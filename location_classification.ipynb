# %%
import pandas as pd
import numpy as np

# %%
# Importing final dataset used by topic clustering model 

clean = pd.read_csv('clean.csv').drop(columns=['Unnamed: 0'])

# %%
clean.shape
# Out:
# (4328, 7)

# %%
clean.head()
# Out:
#   outlet                                 url  \
# 0    cbc    https://www.cbc.ca/news/covid-19
# 1    cbc       https://www.cbc.ca/news/local
# 2    cbc    https://www.cbc.ca/news/politics
# 3    cbc  https://www.cbc.ca/news/indigenous
# 4    cbc    https://www.cbc.ca/news/business
#
#                                              title             authors  \
# 0  CBC News | Information about COVID-19 in Canada  'Darren Bernhardt'
# 1                                         CBC News    'Andrew Kurjata'
# 2                                         Politics  'John Paul Tasker'
# 3                                       Indigenous      'Jessica Deer'
# 4                                         Business        'Pete Evans'
#
#   publish_date                                               text keywords
# 0          NaN  Sylvan Lake to clamp down on beach crowds with...       []
# 1          NaN  What you need to know about COVID-19 in Ottawa...       []
# 2          NaN  WE Charity contract could have been worth up t...       []
# 3          NaN  Manitoba judge points to systemic issues in In...       []
# 4          NaN  Twitter says about 130 accounts were targeted ...       []

# %% [markdown]
# There are 21 unique news outlets in this dataset.

# %%
clean['outlet'].unique()
# Out:
# array(['cbc', 'ctvnews', 'nationalpost', 'torontosun', 'thestar', 'cp24',
#        'mapleridgenews', 'tricitynews', 'langleyadvancetimes', 'abbynews',
#        'theprogress', 'northdeltareporter', 'surreynowleader',
#        'vancouverobserver', 'vancourier', 'nsnews', 'richmond-news',
#        'burnabynow', 'newwestrecord', 'bowenislandundercurrent',
#        'The Record'], dtype=object)

# %% [markdown]
# **Options for location-based coordinates for Demo Day:**
#
# 1. Count number of locations in the text and find coordinates of most frequent
#     - spacy API
#
# 2. Use location of outlet (21 unique locations)

# %% [markdown]
# **Pipeline:**
#
# - For all text that have GPE (location) items,
#         - Count occurrences of location names in text
#         - Select most frequently mentioned location  **(1A)**
#
# - For text without GPE item,
#         - Select location of news outlet  **(1B)**
#
#
# - Find coordinates of location **(2)**
#         - use mapbox API and forward geocoding (https://docs.mapbox.com/api/search/#forward-geocoding)
#         - Add noise to lat and long coordinates

# %% [markdown]
# ## (1) Determining location of article

# %%
import spacy

# %% [markdown]
# ### Create dictionary of news outlets and location

# %%
def find_location(text, model):
    
    doc = model(text)
    final_loc = ''
    locations = []
    
    for ent in doc.ents:
        if (ent.label_ == 'GPE'):
            locations.append(ent.text)
            #print(ent.text, ent.start_char, ent.end_char, ent.label_)
    
    if len(locations) > 0:
        loc_counts = pd.DataFrame([[x, locations.count(x)] for x in set(locations)])
        loc_counts.columns = ['location', 'count']
        loc_counts = loc_counts.sort_values(by=['count'], ascending=False)
    
        final_loc = loc_counts.iloc[0, 0]
        
    return final_loc

# %% [markdown]
# ### Creating new .csv of articles with locations

# %%
new_clean = clean

# %%
# Model to use for location 

nlp = spacy.load("en_core_web_sm")

# %%
count_spacy = 0
count_outlet = 0

# %%
for i in range(len(new_clean)):
    
    # Finding location of article
    print('Row: ' + str(i))
    text_loc = find_location(new_clean.loc[i, 'text'], nlp)
    
    if text_loc=='Surrey':
        text_loc = 'Surrey, British Columbia'
    elif text_loc=='B.C.':
        text_loc = 'British Columbia'
        
    print('Location from spacy: ' + text_loc)
    
    if text_loc != '': 
        try: 
            new_clean.loc[i, 'location'] = text_loc        # (1A)
            loc = gl.geocode(text_loc)
            lat, long = loc.latitude, loc.longitude
            
            print('Coordinates from geopy: [' + str(lat) + ', ' + str(long) + ']' )
            
            new_clean.loc[i, 'lat'] = lat
            new_clean.loc[i, 'long'] = long
                
            count_spacy +=1
            
        except:
            print("Error with .")
            new_clean.loc[i, 'lat'] = 0.0
            new_clean.loc[i, 'long'] = 0.0
            
    else:
        try:
            new_clean.loc[i, 'location'] = loc_dict[new_clean.loc[i, 'outlet']]      # (1B)
            new_clean.loc[i, 'lat'] = lat_dict[new_clean.loc[i, 'outlet']] 
            new_clean.loc[i, 'long'] = long_dict[new_clean.loc[i, 'outlet']]  
            count_outlet += 1
        except:
            print("Error calling from dictionaries.")
# Out:
# Row: 0
# Location from spacy: Alberta
# Coordinates from geopy: [55.001251, -115.002136]
# Row: 1
# Location from spacy: Ottawa
# Coordinates from geopy: [45.421106, -75.690308]
# Row: 2
# Location from spacy:
# Row: 3
# Location from spacy: Manitoba
# Coordinates from geopy: [55.001251, -97.001038]
# Row: 4
# Location from spacy:
# Row: 5
# Location from spacy:
# Row: 6
# Location from spacy:
# Row: 7
# Location from spacy: N.S.
# Coordinates from geopy: [24.4349856, 105.5550331]
# Row: 8
# Location from spacy:
# Row: 9
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 10
# Location from spacy: Greece
# Coordinates from geopy: [38.9953683, 21.9877132]
# Row: 11
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 12
# Location from spacy:
# Row: 13
# Location from spacy: Moscow
# Coordinates from geopy: [55.7504461, 37.6174943]
# Row: 14
# Location from spacy: Jordan
# Coordinates from geopy: [31.1667049, 36.941628]
# Row: 15
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 16
# Location from spacy: Montreal
# Coordinates from geopy: [45.4972159, -73.6103642]
# Row: 17
# Location from spacy: Edinburgh
# Coordinates from geopy: [55.9533456, -3.1883749]
# Row: 18
# Location from spacy: Britain
# Coordinates from geopy: [54.7023545, -3.2765753]
# Row: 19
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 20
# Location from spacy: Bordeaux
# Coordinates from geopy: [44.841225, -0.5800364]
# Row: 21
# Location from spacy: U.S.
# Coordinates from geopy: [45.1895845, -88.73215845]
# Row: 22
# Location from spacy: Trinidad
# Coordinates from geopy: [10.443024300000001, -61.26130538878063]
# Row: 23
# Location from spacy: U.S.
# Coordinates from geopy: [45.1895845, -88.73215845]
# Row: 24
# Location from spacy: U.S.
# Coordinates from geopy: [45.1895845, -88.73215845]
# Row: 25
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 26
# Location from spacy: British Columbia
# Coordinates from geopy: [55.001251, -125.002441]
# Row: 27
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 28
# Location from spacy: Romy
# Coordinates from geopy: [24.7823495, 125.2948325]
# Row: 29
# Location from spacy: Toronto
# Coordinates from geopy: [43.6534817, -79.3839347]
# Row: 30
# Location from spacy: Quebec
# Coordinates from geopy: [52.4760892, -71.8258668]
# Row: 31
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 32
# Location from spacy: Ottawa
# Coordinates from geopy: [45.421106, -75.690308]
# Row: 33
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 34
# Location from spacy: Ontario
# Coordinates from geopy: [50.000678, -86.000977]
# Row: 35
# Location from spacy: Montreal
# Coordinates from geopy: [45.4972159, -73.6103642]
# Row: 36
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 37
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 38
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 39
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 40
# Location from spacy: Toronto
# Coordinates from geopy: [43.6534817, -79.3839347]
# Row: 41
# Location from spacy: Toronto
# Coordinates from geopy: [43.6534817, -79.3839347]
# Row: 42
# Location from spacy: Toronto
# Coordinates from geopy: [43.6534817, -79.3839347]
# Row: 43
# Location from spacy: Vezina
# Coordinates from geopy: [46.8755026, -71.0317576]
# Row: 44
# Location from spacy: Ohio
# Coordinates from geopy: [40.2253569, -82.6881395]
# Row: 45
# Location from spacy: U.S.
# Coordinates from geopy: [45.1895845, -88.73215845]
# Row: 46
# Location from spacy: Tokyo
# Coordinates from geopy: [35.6828387, 139.7594549]
# Row: 47
# Location from spacy: Toronto
# Coordinates from geopy: [43.6534817, -79.3839347]
# Row: 48
# Location from spacy: Toronto
# Coordinates from geopy: [43.6534817, -79.3839347]
# Row: 49
# Location from spacy: U.S.
# Coordinates from geopy: [45.1895845, -88.73215845]
# Row: 50
# Location from spacy: U.S.
# Coordinates from geopy: [45.1895845, -88.73215845]
# Row: 51
# Location from spacy: Muirfield Village
# Coordinates from geopy: [33.42514, -86.619347]
# Row: 52
# Location from spacy: Toronto
# Coordinates from geopy: [43.6534817, -79.3839347]
# Row: 53
# Location from spacy: Atlanta
# Coordinates from geopy: [33.7490987, -84.3901849]
# Row: 54
# Location from spacy: Madrid
# Coordinates from geopy: [40.4167047, -3.7035825]
# Row: 55
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 56
# Location from spacy: Washington
# Coordinates from geopy: [38.8949855, -77.0365708]
# Row: 57
# Location from spacy: Toronto
# Coordinates from geopy: [43.6534817, -79.3839347]
# Row: 58
# Location from spacy: Ontario
# Coordinates from geopy: [50.000678, -86.000977]
# Row: 59
# Location from spacy: Smoliga
# Error with .
# Row: 60
# Location from spacy: Hollywood
# Coordinates from geopy: [34.0980031, -118.3295232]
# Row: 61
# Location from spacy: U.S.
# Coordinates from geopy: [45.1895845, -88.73215845]
# Row: 62
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 63
# Location from spacy: Fort McMurray
# Coordinates from geopy: [56.7291997, -111.3885221]
# Row: 64
# Location from spacy: London
# Coordinates from geopy: [51.5073219, -0.1276474]
# Row: 65
# Location from spacy: Ottawa
# Coordinates from geopy: [45.421106, -75.690308]
# Row: 66
# Location from spacy: Bethesda
# Coordinates from geopy: [38.9819845, -77.12423413116392]
# Row: 67
# Location from spacy: British Columbia's
# Coordinates from geopy: [49.24402705, -121.7638096066843]
# Row: 68
# Location from spacy: Holland
# Coordinates from geopy: [52.5001698, 5.7480821]
# Row: 69
# Location from spacy: Oshawa
# Coordinates from geopy: [43.91768, -78.862953]
# Row: 70
# Location from spacy: the United Kingdom
# Coordinates from geopy: [54.7023545, -3.2765753]
# Row: 71
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 72
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 73
# Location from spacy: U.S.
# Coordinates from geopy: [45.1895845, -88.73215845]
# Row: 74
# Location from spacy: England
# Coordinates from geopy: [52.7954791, -0.5402402866174321]
# Row: 75
# Location from spacy: Rushton
# Coordinates from geopy: [52.4393998, -0.7656317]
# Row: 76
# Location from spacy: Washington
# Coordinates from geopy: [38.8949855, -77.0365708]
# Row: 77
# Location from spacy: U.S.A.
# Coordinates from geopy: [31.1932768, 30.0540191]
# Row: 78
# Location from spacy: British Columbia
# Coordinates from geopy: [55.001251, -125.002441]
# Row: 79
# Location from spacy: Pakistan
# Coordinates from geopy: [30.3308401, 71.247499]
# Row: 80
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 81
# Location from spacy: Ontario
# Coordinates from geopy: [50.000678, -86.000977]
# Row: 82
# Location from spacy: Toronto
# Coordinates from geopy: [43.6534817, -79.3839347]
# Row: 83
# Location from spacy:
# Row: 84
# Location from spacy: Newfoundland
# Coordinates from geopy: [49.12120935, -56.69629621274099]
# Row: 85
# Location from spacy: Alberta
# Coordinates from geopy: [55.001251, -115.002136]
# Row: 86
# Location from spacy: Hong Kong
# Coordinates from geopy: [22.2793278, 114.1628131]
# Row: 87
# Location from spacy: Aquafaba
# Error with .
# Row: 88
# Location from spacy: Minden
# Coordinates from geopy: [52.2881045, 8.9168852]
# Row: 89
# Location from spacy: Toronto
# Coordinates from geopy: [43.6534817, -79.3839347]
# Row: 90
# Location from spacy: Junia
# Coordinates from geopy: [4.6135696, -73.9189352487911]
# Row: 91
# Location from spacy: Clairmont
# Coordinates from geopy: [55.2623283, -118.7906709]
# Row: 92
# Location from spacy: Montreal
# Coordinates from geopy: [45.4972159, -73.6103642]
# Row: 93
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 94
# Location from spacy: Wintersleep
# Error with .
# Row: 95
# Location from spacy:
# Row: 96
# Location from spacy: Quebec
# Coordinates from geopy: [52.4760892, -71.8258668]
# Row: 97
# Location from spacy: US
# Coordinates from geopy: [39.7837304, -100.4458825]
# Row: 98
# Location from spacy: Salt Spring Island
# Coordinates from geopy: [48.8296672, -123.51516139891447]
# Row: 99
# Location from spacy: Toronto
# Coordinates from geopy: [43.6534817, -79.3839347]
# Row: 100
# Location from spacy: British Columbia
# Coordinates from geopy: [55.001251, -125.002441]
# Row: 101
# Location from spacy: Italy
# Coordinates from geopy: [42.6384261, 12.674297]
# Row: 102
# Location from spacy: Toronto
# Coordinates from geopy: [43.6534817, -79.3839347]
# Row: 103
# Location from spacy: Orchestre Métropolitain
# Error with .
# Row: 104
# Location from spacy: Montreal
# Coordinates from geopy: [45.4972159, -73.6103642]
# Row: 105
# Location from spacy: New Orleans
# Coordinates from geopy: [29.9499323, -90.0701156]
# Row: 106
# Location from spacy: Victoria
# Coordinates from geopy: [-36.5986096, 144.6780052]
# Row: 107
# Location from spacy: Toronto
# Coordinates from geopy: [43.6534817, -79.3839347]
# Row: 108
# Location from spacy: Cambodia
# Coordinates from geopy: [13.5066394, 104.869423]
# Row: 109
# Location from spacy: Xoxox
# Error with .
# Row: 110
# Location from spacy: Alessia
# Coordinates from geopy: [40.6855514, 14.7325899]
# Row: 111
# Location from spacy:
# Row: 112
# Location from spacy: Weeknd
# Coordinates from geopy: [10.4273236, -85.0943199]
# Row: 113
# Location from spacy: Toronto
# Coordinates from geopy: [43.6534817, -79.3839347]
# Row: 114
# Location from spacy: Labrador
# Coordinates from geopy: [55.9266344, -61.88499184409646]
# Row: 115
# Location from spacy: Vancouver
# Coordinates from geopy: [49.2608724, -123.1139529]
# Row: 116
# Location from spacy: Toronto
# Coordinates from geopy: [43.6534817, -79.3839347]
# Row: 117
# Location from spacy:
# Row: 118
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 119
# Location from spacy: Calgary
# Coordinates from geopy: [51.0534234, -114.0625892]
# Row: 120
# Location from spacy: Jensplaining
# Error with .
# Row: 121
# Location from spacy:
# Row: 122
# Location from spacy: Toronto
# Coordinates from geopy: [43.6534817, -79.3839347]
# Row: 123
# Location from spacy: Ontario
# Coordinates from geopy: [50.000678, -86.000977]
# Row: 124
# Location from spacy: Toronto
# Coordinates from geopy: [43.6534817, -79.3839347]
# Row: 125
# Location from spacy: Ontario
# Coordinates from geopy: [50.000678, -86.000977]
# Row: 126
# Location from spacy: Gisella
# Coordinates from geopy: [51.042934, 3.7591869]
# Row: 127
# Location from spacy: U.S.
# Coordinates from geopy: [45.1895845, -88.73215845]
# Row: 128
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 129
# Location from spacy: British Columbia
# Coordinates from geopy: [55.001251, -125.002441]
# Row: 130
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 131
# Location from spacy: Quebec
# Coordinates from geopy: [52.4760892, -71.8258668]
# Row: 132
# Location from spacy: Willow Creek
# Coordinates from geopy: [42.5937226, -84.4507171]
# Row: 133
# Location from spacy: U.S.
# Coordinates from geopy: [45.1895845, -88.73215845]
# Row: 134
# Location from spacy: U.S.
# Coordinates from geopy: [45.1895845, -88.73215845]
# Row: 135
# Location from spacy: Texas
# Coordinates from geopy: [31.8160381, -99.5120986]
# Row: 136
# Location from spacy: India
# Coordinates from geopy: [22.3511148, 78.6677428]
# Row: 137
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 138
# Location from spacy: Halifax
# Coordinates from geopy: [44.648618, -63.5859487]
# Row: 139
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 140
# Location from spacy: Manitoba
# Coordinates from geopy: [55.001251, -97.001038]
# Row: 141
# Location from spacy: Ontario
# Coordinates from geopy: [50.000678, -86.000977]
# Row: 142
# Location from spacy: Nova Scotia
# Coordinates from geopy: [45.1960403, -63.1653789]
# Row: 143
# Location from spacy: Ontario
# Coordinates from geopy: [50.000678, -86.000977]
# Row: 144
# Location from spacy: Quebec
# Coordinates from geopy: [52.4760892, -71.8258668]
# Row: 145
# Location from spacy: Sri Lanka
# Coordinates from geopy: [7.5554942, 80.7137847]
# Row: 146
# Location from spacy: OTTAWA
# Coordinates from geopy: [45.421106, -75.690308]
# Row: 147
# Location from spacy: U.S.
# Coordinates from geopy: [45.1895845, -88.73215845]
# Row: 148
# Location from spacy: Quebec City
# Coordinates from geopy: [46.8259601, -71.2352226]
# Row: 149
# Location from spacy: Georgia
# Coordinates from geopy: [32.3293809, -83.1137366]
# Row: 150
# Location from spacy:
# Row: 151
# Location from spacy: Nigeria
# Coordinates from geopy: [9.6000359, 7.9999721]
# Row: 152
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 153
# Location from spacy: Dayspring
# Coordinates from geopy: [44.3783816, -64.4718806]
# Row: 154
# Location from spacy: Airbnb
# Coordinates from geopy: [48.3035927, -4.5628815]
# Row: 155
# Location from spacy: U.S.
# Coordinates from geopy: [45.1895845, -88.73215845]
# Row: 156
# Location from spacy: U.S.
# Coordinates from geopy: [45.1895845, -88.73215845]
# Row: 157
# Location from spacy: Bridger
# Coordinates from geopy: [45.2957807, -108.9137544]
# Row: 158
# Location from spacy: CP24
# Coordinates from geopy: [43.6497652, -79.3907305]
# Row: 159
# Location from spacy: Ontario
# Coordinates from geopy: [50.000678, -86.000977]
# Row: 160
# Location from spacy: Ottawa
# Coordinates from geopy: [45.421106, -75.690308]
# Row: 161
# Location from spacy: Minden
# Coordinates from geopy: [52.2881045, 8.9168852]
# Row: 162
# Location from spacy: Toronto
# Coordinates from geopy: [43.6534817, -79.3839347]
# Row: 163
# Location from spacy: Russia
# Coordinates from geopy: [64.6863136, 97.7453061]
# Row: 164
# Location from spacy: Iowa
# Coordinates from geopy: [41.9216734, -93.3122705]
# Row: 165
# Location from spacy: Los Angeles
# Coordinates from geopy: [34.0536909, -118.2427666]
# Row: 166
# Location from spacy: Bridger
# Coordinates from geopy: [45.2957807, -108.9137544]
# Row: 167
# Location from spacy: Russia
# Coordinates from geopy: [64.6863136, 97.7453061]
# Row: 168
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 169
# Location from spacy: OTTAWA
# Coordinates from geopy: [45.421106, -75.690308]
# Row: 170
# Location from spacy: U.S.
# Coordinates from geopy: [45.1895845, -88.73215845]
# Row: 171
# Location from spacy: Japan
# Coordinates from geopy: [36.5748441, 139.2394179]
# Row: 172
# Location from spacy: FRANCE
# Coordinates from geopy: [46.603354, 1.8883335]
# Row: 173
# Location from spacy: LONDON
# Coordinates from geopy: [51.5073219, -0.1276474]
# Row: 174
# Location from spacy: New York
# Coordinates from geopy: [40.7127281, -74.0060152]
# Row: 175
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 176
# Location from spacy: U.S.
# Coordinates from geopy: [45.1895845, -88.73215845]
# Row: 177
# Location from spacy: Australia
# Coordinates from geopy: [-24.7761086, 134.755]
# Row: 178
# Location from spacy: U.S.
# Coordinates from geopy: [45.1895845, -88.73215845]
# Row: 179
# Location from spacy: the United States
# Coordinates from geopy: [39.7837304, -100.4458825]
# Row: 180
# Location from spacy: District of Columbia
# Coordinates from geopy: [38.893661249999994, -76.98788325388196]
# Row: 181
# Location from spacy: Japan
# Coordinates from geopy: [36.5748441, 139.2394179]
# Row: 182
# Location from spacy: Vancouver
# Coordinates from geopy: [49.2608724, -123.1139529]
# Row: 183
# Location from spacy: Pennsylvania
# Coordinates from geopy: [40.9699889, -77.7278831]
# Row: 184
# Location from spacy: Japan
# Coordinates from geopy: [36.5748441, 139.2394179]
# Row: 185
# Location from spacy: N.S.
# Coordinates from geopy: [24.4349856, 105.5550331]
# Row: 186
# Location from spacy: Vancouver
# Coordinates from geopy: [49.2608724, -123.1139529]
# Row: 187
# Location from spacy: Seattle
# Coordinates from geopy: [47.6038321, -122.3300624]
# Row: 188
# Location from spacy: Toronto
# Coordinates from geopy: [43.6534817, -79.3839347]
# Row: 189
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 190
# Location from spacy: California
# Coordinates from geopy: [36.7014631, -118.7559974]
# Row: 191
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 192
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 193
# Location from spacy: U.S.
# Coordinates from geopy: [45.1895845, -88.73215845]
# Row: 194
# Location from spacy: Ontario
# Coordinates from geopy: [50.000678, -86.000977]
# Row: 195
# Location from spacy: U.S.
# Coordinates from geopy: [45.1895845, -88.73215845]
# Row: 196
# Location from spacy:
# Row: 197
# Location from spacy: Calgary
# Coordinates from geopy: [51.0534234, -114.0625892]
# Row: 198
# Location from spacy: Ottawa
# Coordinates from geopy: [45.421106, -75.690308]
# Row: 199
# Location from spacy:
# Row: 200
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 201
# Location from spacy: Ottawa
# Coordinates from geopy: [45.421106, -75.690308]
# Row: 202
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 203
# Location from spacy:
# Row: 204
# Location from spacy: Alberta
# Coordinates from geopy: [55.001251, -115.002136]
# Row: 205
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 206
# Location from spacy: British Columbia
# Coordinates from geopy: [55.001251, -125.002441]
# Row: 207
# Location from spacy:
# Row: 208
# Location from spacy: McKnight
# Coordinates from geopy: [40.5550681, -80.0364448]
# Row: 209
# Location from spacy: Edmonton
# Coordinates from geopy: [53.535411, -113.507996]
# Row: 210
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 211
# Location from spacy: Edmonton
# Coordinates from geopy: [53.535411, -113.507996]
# Row: 212
# Location from spacy: Quebec
# Coordinates from geopy: [52.4760892, -71.8258668]
# Row: 213
# Location from spacy: Alberta
# Coordinates from geopy: [55.001251, -115.002136]
# Row: 214
# Location from spacy:
# Row: 215
# Location from spacy: Fort McMurray
# Coordinates from geopy: [56.7291997, -111.3885221]
# Row: 216
# Location from spacy:
# Row: 217
# Location from spacy:
# Row: 218
# Location from spacy: Alberta
# Coordinates from geopy: [55.001251, -115.002136]
# Row: 219
# Location from spacy: Alberta
# Coordinates from geopy: [55.001251, -115.002136]
# Row: 220
# Location from spacy: Alberta
# Coordinates from geopy: [55.001251, -115.002136]
# Row: 221
# Location from spacy:
# Row: 222
# Location from spacy: the Winspear Centre
# Coordinates from geopy: [53.5440695, -113.4876501481439]
# Row: 223
# Location from spacy: Alberta
# Coordinates from geopy: [55.001251, -115.002136]
# Row: 224
# Location from spacy: Edmonton
# Coordinates from geopy: [53.535411, -113.507996]
# Row: 225
# Location from spacy: Wetaskiwin
# Coordinates from geopy: [52.968492, -113.36792]
# Row: 226
# Location from spacy: Edmonton
# Coordinates from geopy: [53.535411, -113.507996]
# Row: 227
# Location from spacy: Parkland County
# Coordinates from geopy: [53.5050612, -114.3529154]
# Row: 228
# Location from spacy: Edmonton
# Coordinates from geopy: [53.535411, -113.507996]
# Row: 229
# Location from spacy: Vancouver
# Coordinates from geopy: [49.2608724, -123.1139529]
# Row: 230
# Location from spacy: Calgary
# Coordinates from geopy: [51.0534234, -114.0625892]
# Row: 231
# Location from spacy: Calgary
# Coordinates from geopy: [51.0534234, -114.0625892]
# Row: 232
# Location from spacy: Toronto
# Coordinates from geopy: [43.6534817, -79.3839347]
# Row: 233
# Location from spacy: Brighton
# Coordinates from geopy: [50.8220399, -0.1374061]
# Row: 234
# Location from spacy:
# Row: 235
# Location from spacy: Saskatchewan
# Coordinates from geopy: [55.5321257, -106.1412243]
# Row: 236
# Location from spacy: Regina
# Coordinates from geopy: [50.44876, -104.61731]
# Row: 237
# Location from spacy:
# Row: 238
# Location from spacy: Manitoba
# Coordinates from geopy: [55.001251, -97.001038]
# Row: 239
# Location from spacy:
# Row: 240
# Location from spacy: The City of Vancouver
# Coordinates from geopy: [49.2608724, -123.1139529]
# Row: 241
# Location from spacy: Vancouver
# Coordinates from geopy: [49.2608724, -123.1139529]
# Row: 242
# Location from spacy: British Columbia
# Coordinates from geopy: [55.001251, -125.002441]
# Row: 243
# Location from spacy: Vancouver
# Coordinates from geopy: [49.2608724, -123.1139529]
# Row: 244
# Location from spacy: Langford
# Coordinates from geopy: [48.4497693, -123.5046662]
# Row: 245
# Location from spacy: Toronto
# Coordinates from geopy: [43.6534817, -79.3839347]
# Row: 246
# Location from spacy: Greater Toronto
# Coordinates from geopy: [51.42936555, 0.10139469856643134]
# Row: 247
# Location from spacy: MONTREAL
# Coordinates from geopy: [45.4972159, -73.6103642]
# Row: 248
# Location from spacy: Cornwallis Park
# Coordinates from geopy: [44.6531081, -65.6304344]
# Row: 249
# Location from spacy: N.S.
# Coordinates from geopy: [24.4349856, 105.5550331]
# Row: 250
# Location from spacy: the City of London
# Coordinates from geopy: [51.5156177, -0.0919983]
# Row: 251
# Location from spacy: London
# Coordinates from geopy: [51.5073219, -0.1276474]
# Row: 252
# Location from spacy: London
# Coordinates from geopy: [51.5073219, -0.1276474]
# Row: 253
# Location from spacy: Plexiglas
# Coordinates from geopy: [48.8745529, 2.3890986]
# Row: 254
# Location from spacy:
# Row: 255
# Location from spacy:
# Row: 256
# Location from spacy: Waterloo Region
# Coordinates from geopy: [43.4586422, -80.5194113]
# Row: 257
# Location from spacy:
# Row: 258
# Location from spacy:
# Row: 259
# Location from spacy: Ontario
# Coordinates from geopy: [50.000678, -86.000977]
# Row: 260
# Location from spacy: OTTAWA
# Coordinates from geopy: [45.421106, -75.690308]
# Row: 261
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 262
# Location from spacy: Russia
# Coordinates from geopy: [64.6863136, 97.7453061]
# Row: 263
# Location from spacy: OTTAWA
# Coordinates from geopy: [45.421106, -75.690308]
# Row: 264
# Location from spacy: U.S.
# Coordinates from geopy: [45.1895845, -88.73215845]
# Row: 265
# Location from spacy: Ontario
# Coordinates from geopy: [50.000678, -86.000977]
# Row: 266
# Location from spacy: Ottawa
# Coordinates from geopy: [45.421106, -75.690308]
# Row: 267
# Location from spacy: OTTAWA
# Coordinates from geopy: [45.421106, -75.690308]
# Row: 268
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 269
# Location from spacy: New York
# Coordinates from geopy: [40.7127281, -74.0060152]
# Row: 270
# Location from spacy: Macdonald
# Coordinates from geopy: [37.8892797, -81.1609347]
# Row: 271
# Location from spacy:
# Row: 272
# Location from spacy: Idaho
# Coordinates from geopy: [43.6447642, -114.0154071]
# Row: 273
# Location from spacy: U.S.
# Coordinates from geopy: [45.1895845, -88.73215845]
# Row: 274
# Location from spacy: Gooding
# Coordinates from geopy: [43.0031041, -114.8286924]
# Row: 275
# Location from spacy: LOS ANGELES
# Coordinates from geopy: [34.0536909, -118.2427666]
# Row: 276
# Location from spacy: Colville
# Coordinates from geopy: [48.5465695, -117.905537]
# Row: 277
# Location from spacy: Sioux City
# Coordinates from geopy: [42.4966815, -96.4058782]
# Row: 278
# Location from spacy: Los Angeles
# Coordinates from geopy: [34.0536909, -118.2427666]
# Row: 279
# Location from spacy: Quebec
# Coordinates from geopy: [52.4760892, -71.8258668]
# Row: 280
# Location from spacy: Josey
# Coordinates from geopy: [-27.69759, 152.9293456]
# Row: 281
# Location from spacy: Toronto
# Coordinates from geopy: [43.6534817, -79.3839347]
# Row: 282
# Location from spacy: Britain
# Coordinates from geopy: [54.7023545, -3.2765753]
# Row: 283
# Location from spacy: America
# Coordinates from geopy: [51.44770365, 5.966069282055592]
# Row: 284
# Location from spacy: British Columbia
# Coordinates from geopy: [55.001251, -125.002441]
# Row: 285
# Location from spacy: British Columbia
# Coordinates from geopy: [55.001251, -125.002441]
# Row: 286
# Location from spacy: Vancouver
# Coordinates from geopy: [49.2608724, -123.1139529]
# Row: 287
# Location from spacy: Surrey, British Columbia
# Coordinates from geopy: [49.1913033, -122.8491439]
# Row: 288
# Location from spacy: British Columbia
# Coordinates from geopy: [55.001251, -125.002441]
# Row: 289
# Location from spacy: VPD
# Coordinates from geopy: [60.2921906, 25.0420973]
# Row: 290
# Location from spacy:
# Row: 291
# Location from spacy: British Columbia
# Coordinates from geopy: [55.001251, -125.002441]
# Row: 292
# Location from spacy: Kelowna
# Coordinates from geopy: [49.889326, -119.498291]
# Row: 293
# Location from spacy:
# Row: 294
# Location from spacy: British Columbia
# Coordinates from geopy: [55.001251, -125.002441]
# Row: 295
# Location from spacy: Kelowna
# Coordinates from geopy: [49.889326, -119.498291]
# Row: 296
# Location from spacy: Vancouver Island
# Coordinates from geopy: [49.592949450000006, -125.70255696124094]
# Row: 297
# Location from spacy: British Columbia
# Coordinates from geopy: [55.001251, -125.002441]
# Row: 298
# Location from spacy: British Columbia
# Coordinates from geopy: [55.001251, -125.002441]
# Row: 299
# Location from spacy: British Columbia
# Coordinates from geopy: [55.001251, -125.002441]
# Row: 300
# Location from spacy: British Columbia
# Coordinates from geopy: [55.001251, -125.002441]
# Row: 301
# Location from spacy: Vancouver
# Coordinates from geopy: [49.2608724, -123.1139529]
# Row: 302
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 303
# Location from spacy: Vancouver
# Coordinates from geopy: [49.2608724, -123.1139529]
# Row: 304
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 305
# Location from spacy: British Columbia
# Coordinates from geopy: [55.001251, -125.002441]
# Row: 306
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 307
# Location from spacy: Langley
# Coordinates from geopy: [48.3604648, 6.3258262]
# Row: 308
# Location from spacy:
# Row: 309
# Location from spacy: New Westminster
# Coordinates from geopy: [49.2067726, -122.9108818]
# Row: 310
# Location from spacy: Vancouver
# Coordinates from geopy: [49.2608724, -123.1139529]
# Row: 311
# Location from spacy: South Burnaby
# Coordinates from geopy: [49.2433804, -122.9725459]
# Row: 312
# Location from spacy: Coquitlam
# Coordinates from geopy: [49.2842958, -122.793281]
# Row: 313
# Location from spacy: British Columbia
# Coordinates from geopy: [55.001251, -125.002441]
# Row: 314
# Location from spacy: U.S.
# Coordinates from geopy: [45.1895845, -88.73215845]
# Row: 315
# Location from spacy: British Columbia
# Coordinates from geopy: [55.001251, -125.002441]
# Row: 316
# Location from spacy: News Westminster
# Coordinates from geopy: [37.319828099999995, -76.73955266153908]
# Row: 317
# Location from spacy: kamado
# Coordinates from geopy: [14.4024277, 5.1738704]
# Row: 318
# Location from spacy: the United States
# Coordinates from geopy: [39.7837304, -100.4458825]
# Row: 319
# Location from spacy:
# Row: 320
# Location from spacy: Vancouver
# Coordinates from geopy: [49.2608724, -123.1139529]
# Row: 321
# Location from spacy:
# Row: 322
# Location from spacy:
# Row: 323
# Location from spacy:
# Row: 324
# Location from spacy:
# Row: 325
# Location from spacy:
# Row: 326
# Location from spacy: Talerico
# Coordinates from geopy: [33.7217751, -84.759936]
# Row: 327
# Location from spacy: Leamington
# Coordinates from geopy: [52.2913394, -1.536404]
# Row: 328
# Location from spacy:
# Row: 329
# Location from spacy:
# Row: 330
# Location from spacy: Fort Malden
# Coordinates from geopy: [42.1071799, -83.1133054]
# Row: 331
# Location from spacy: Windsor
# Coordinates from geopy: [51.48379805, -0.6041397427111339]
# Row: 332
# Location from spacy: Windsor
# Coordinates from geopy: [51.48379805, -0.6041397427111339]
# Row: 333
# Location from spacy: Michigan
# Coordinates from geopy: [43.6211955, -84.6824346]
# Row: 334
# Location from spacy: LaSalle
# Coordinates from geopy: [41.3474892, -88.9011861]
# Row: 335
# Location from spacy: Ontario
# Coordinates from geopy: [50.000678, -86.000977]
# Row: 336
# Location from spacy: U.S.
# Coordinates from geopy: [45.1895845, -88.73215845]
# Row: 337
# Location from spacy: Tecumseh
# Coordinates from geopy: [42.0039331, -83.9449417]
# Row: 338
# Location from spacy: Windsor-Essex
# Coordinates from geopy: [51.8404615, 1.038843080509556]
# Row: 339
# Location from spacy:
# Row: 340
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 341
# Location from spacy: the City of Windsor
# Coordinates from geopy: [42.2858536, -82.9780695]
# Row: 342
# Location from spacy:
# Row: 343
# Location from spacy:
# Row: 344
# Location from spacy: Sarnia
# Coordinates from geopy: [42.9746137, -82.4065585]
# Row: 345
# Location from spacy: London
# Coordinates from geopy: [51.5073219, -0.1276474]
# Row: 346
# Location from spacy: London
# Coordinates from geopy: [51.5073219, -0.1276474]
# Row: 347
# Location from spacy: London
# Coordinates from geopy: [51.5073219, -0.1276474]
# Row: 348
# Location from spacy: Norfolk County
# Coordinates from geopy: [42.1538607, -71.1828015]
# Row: 349
# Location from spacy: LONDON
# Coordinates from geopy: [51.5073219, -0.1276474]
# Row: 350
# Location from spacy: London
# Coordinates from geopy: [51.5073219, -0.1276474]
# Row: 351
# Location from spacy: London
# Coordinates from geopy: [51.5073219, -0.1276474]
# Row: 352
# Location from spacy: LONDON
# Coordinates from geopy: [51.5073219, -0.1276474]
# Row: 353
# Location from spacy: Ontario
# Coordinates from geopy: [50.000678, -86.000977]
# Row: 354
# Location from spacy:
# Row: 355
# Location from spacy: Queen’s Park
# Coordinates from geopy: [43.659659, -79.3903399]
# Row: 356
# Location from spacy: London
# Coordinates from geopy: [51.5073219, -0.1276474]
# Row: 357
# Location from spacy: mybigyellowbus.ca
# Error with .
# Row: 358
# Location from spacy: London
# Coordinates from geopy: [51.5073219, -0.1276474]
# Row: 359
# Location from spacy: London
# Coordinates from geopy: [51.5073219, -0.1276474]
# Row: 360
# Location from spacy: London
# Coordinates from geopy: [51.5073219, -0.1276474]
# Row: 361
# Location from spacy: London
# Coordinates from geopy: [51.5073219, -0.1276474]
# Row: 362
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 363
# Location from spacy: LONDON
# Coordinates from geopy: [51.5073219, -0.1276474]
# Row: 364
# Location from spacy: St. Thomas
# Coordinates from geopy: [49.4972, 3.82019]
# Row: 365
# Location from spacy: London
# Coordinates from geopy: [51.5073219, -0.1276474]
# Row: 366
# Location from spacy: Ontario
# Coordinates from geopy: [50.000678, -86.000977]
# Row: 367
# Location from spacy:
# Row: 368
# Location from spacy: Vita
# Coordinates from geopy: [40.8113662, -5.0053801]
# Row: 369
# Location from spacy:
# Row: 370
# Location from spacy:
# Row: 371
# Location from spacy: Ottawa
# Coordinates from geopy: [45.421106, -75.690308]
# Row: 372
# Location from spacy: North End
# Coordinates from geopy: [42.3650974, -71.0544954]
# Row: 373
# Location from spacy:
# Row: 374
# Location from spacy: Thompson
# Coordinates from geopy: [55.743347, -97.863464]
# Row: 375
# Location from spacy: South St. Boniface
# Coordinates from geopy: [46.505246, -72.828712]
# Row: 376
# Location from spacy: Manitoba
# Coordinates from geopy: [55.001251, -97.001038]
# Row: 377
# Location from spacy: Manitoba
# Coordinates from geopy: [55.001251, -97.001038]
# Row: 378
# Location from spacy: Manitoba
# Coordinates from geopy: [55.001251, -97.001038]
# Row: 379
# Location from spacy: Ottawa
# Coordinates from geopy: [45.421106, -75.690308]
# Row: 380
# Location from spacy: Manitoba
# Coordinates from geopy: [55.001251, -97.001038]
# Row: 381
# Location from spacy: the City of Winnipeg
# Coordinates from geopy: [49.9003692, -97.09560620118683]
# Row: 382
# Location from spacy: Manitoba
# Coordinates from geopy: [55.001251, -97.001038]
# Row: 383
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 384
# Location from spacy:
# Row: 385
# Location from spacy: Finland
# Coordinates from geopy: [63.2467777, 25.9209164]
# Row: 386
# Location from spacy: Manitoba
# Coordinates from geopy: [55.001251, -97.001038]
# Row: 387
# Location from spacy: Manitoba
# Coordinates from geopy: [55.001251, -97.001038]
# Row: 388
# Location from spacy: Michigan
# Coordinates from geopy: [43.6211955, -84.6824346]
# Row: 389
# Location from spacy:
# Row: 390
# Location from spacy:
# Row: 391
# Location from spacy:
# Row: 392
# Location from spacy: Ottawa
# Coordinates from geopy: [45.421106, -75.690308]
# Row: 393
# Location from spacy: Ottawa
# Coordinates from geopy: [45.421106, -75.690308]
# Row: 394
# Location from spacy: Ontario
# Coordinates from geopy: [50.000678, -86.000977]
# Row: 395
# Location from spacy:
# Row: 396
# Location from spacy: Saskatchewan
# Coordinates from geopy: [55.5321257, -106.1412243]
# Row: 397
# Location from spacy: Saskatoon
# Coordinates from geopy: [52.131802, -106.660767]
# Row: 398
# Location from spacy:
# Row: 399
# Location from spacy: Saskatchewan
# Coordinates from geopy: [55.5321257, -106.1412243]
# Row: 400
# Location from spacy: Ottawa
# Coordinates from geopy: [45.421106, -75.690308]
# Row: 401
# Location from spacy: Saskatoon
# Coordinates from geopy: [52.131802, -106.660767]
# Row: 402
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 403
# Location from spacy: Glenside
# Coordinates from geopy: [40.1023326, -75.1521195]
# Row: 404
# Location from spacy:
# Row: 405
# Location from spacy:
# Row: 406
# Location from spacy: Saskatoon
# Coordinates from geopy: [52.131802, -106.660767]
# Row: 407
# Location from spacy: ZYUS
# Error with .
# Row: 408
# Location from spacy: Saskatchewan
# Coordinates from geopy: [55.5321257, -106.1412243]
# Row: 409
# Location from spacy: Alberta
# Coordinates from geopy: [55.001251, -115.002136]
# Row: 410
# Location from spacy: Wisconsin
# Coordinates from geopy: [44.4308975, -89.6884637]
# Row: 411
# Location from spacy: U.S.
# Coordinates from geopy: [45.1895845, -88.73215845]
# Row: 412
# Location from spacy: Edinburgh
# Coordinates from geopy: [55.9533456, -3.1883749]
# Row: 413
# Location from spacy: U.K.
# Coordinates from geopy: [54.7023545, -3.2765753]
# Row: 414
# Location from spacy: Selma
# Coordinates from geopy: [32.4078632, -87.0207473]
# Row: 415
# Location from spacy: Traore
# Coordinates from geopy: [16.068147, 0.0648645]
# Row: 416
# Location from spacy: China
# Coordinates from geopy: [35.000074, 104.999927]
# Row: 417
# Location from spacy: Calgary
# Coordinates from geopy: [51.0534234, -114.0625892]
# Row: 418
# Location from spacy: Calgary
# Coordinates from geopy: [51.0534234, -114.0625892]
# Row: 419
# Location from spacy: Alberta
# Coordinates from geopy: [55.001251, -115.002136]
# Row: 420
# Location from spacy: Alberta
# Coordinates from geopy: [55.001251, -115.002136]
# Row: 421
# Location from spacy: Calgary
# Coordinates from geopy: [51.0534234, -114.0625892]
# Row: 422
# Location from spacy: Ottawa
# Coordinates from geopy: [45.421106, -75.690308]
# Row: 423
# Location from spacy: Calgary
# Coordinates from geopy: [51.0534234, -114.0625892]
# Row: 424
# Location from spacy: Lethbridge
# Coordinates from geopy: [49.694285, -112.851562]
# Row: 425
# Location from spacy: Calgary
# Coordinates from geopy: [51.0534234, -114.0625892]
# Row: 426
# Location from spacy: Calgary
# Coordinates from geopy: [51.0534234, -114.0625892]
# Row: 427
# Location from spacy:
# Row: 428
# Location from spacy: turkey
# Coordinates from geopy: [38.9597594, 34.9249653]
# Row: 429
# Location from spacy: Rwanda
# Coordinates from geopy: [-1.9646631, 30.0644358]
# Row: 430
# Location from spacy: Calgary
# Coordinates from geopy: [51.0534234, -114.0625892]
# Row: 431
# Location from spacy: the Municipal District
# Coordinates from geopy: [61.8600403, 142.8987906]
# Row: 432
# Location from spacy: Ontario
# Coordinates from geopy: [50.000678, -86.000977]
# Row: 433
# Location from spacy: Temagami
# Coordinates from geopy: [46.9736742, -80.07363445]
# Row: 434
# Location from spacy:
# Row: 435
# Location from spacy:
# Row: 436
# Location from spacy: Ontario
# Coordinates from geopy: [50.000678, -86.000977]
# Row: 437
# Location from spacy: U.S.
# Coordinates from geopy: [45.1895845, -88.73215845]
# Row: 438
# Location from spacy: Toronto
# Coordinates from geopy: [43.6534817, -79.3839347]
# Row: 439
# Location from spacy:
# Row: 440
# Location from spacy: Ontario
# Coordinates from geopy: [50.000678, -86.000977]
# Row: 441
# Location from spacy:
# Row: 442
# Location from spacy: Ontario
# Coordinates from geopy: [50.000678, -86.000977]
# Row: 443
# Location from spacy: Compton
# Coordinates from geopy: [33.894927, -118.226624]
# Row: 444
# Location from spacy:
# Row: 445
# Location from spacy: Bracebridge
# Coordinates from geopy: [45.041508, -79.310989]
# Row: 446
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 447
# Location from spacy:
# Row: 448
# Location from spacy:
# Row: 449
# Location from spacy:
# Row: 450
# Location from spacy: Thessalon
# Coordinates from geopy: [46.2638311, -83.5483478]
# Row: 451
# Location from spacy:
# Row: 452
# Location from spacy: Algoma
# Coordinates from geopy: [44.6107841, -87.4387358]
# Row: 453
# Location from spacy: Labrador
# Coordinates from geopy: [55.9266344, -61.88499184409646]
# Row: 454
# Location from spacy: Ontario
# Coordinates from geopy: [50.000678, -86.000977]
# Row: 455
# Location from spacy: Algoma
# Coordinates from geopy: [44.6107841, -87.4387358]
# Row: 456
# Location from spacy: Ontario
# Coordinates from geopy: [50.000678, -86.000977]
# Row: 457
# Location from spacy: Salvage Kings
# Coordinates from geopy: [45.73024605, -65.48922953576567]
# Row: 458
# Location from spacy: Minnowlake
# Error with .
# Row: 459
# Location from spacy: Ontario
# Coordinates from geopy: [50.000678, -86.000977]
# Row: 460
# Location from spacy: Wellington County
# Coordinates from geopy: [43.7590121, -80.4614994]
# Row: 461
# Location from spacy: Norfolk
# Coordinates from geopy: [52.666667, 1.0]
# Row: 462
# Location from spacy: Wilmot Township
# Coordinates from geopy: [45.2448629, -84.67234806471632]
# Row: 463
# Location from spacy: Ontario
# Coordinates from geopy: [50.000678, -86.000977]
# Row: 464
# Location from spacy: St. Agatha
# Coordinates from geopy: [48.3852411, 13.8781989]
# Row: 465
# Location from spacy: Hamilton
# Coordinates from geopy: [43.2560802, -79.8728583]
# Row: 466
# Location from spacy: the Region of Waterloo
# Coordinates from geopy: [43.466874, -80.524635]
# Row: 467
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 468
# Location from spacy: Palubiski
# Coordinates from geopy: [45.5008023, -77.7530433]
# Row: 469
# Location from spacy: Toronto
# Coordinates from geopy: [43.6534817, -79.3839347]
# Row: 470
# Location from spacy:
# Row: 471
# Location from spacy:
# Row: 472
# Location from spacy: Ontario
# Coordinates from geopy: [50.000678, -86.000977]
# Row: 473
# Location from spacy: Ontario
# Coordinates from geopy: [50.000678, -86.000977]
# Row: 474
# Location from spacy: Minden
# Coordinates from geopy: [52.2881045, 8.9168852]
# Row: 475
# Location from spacy: Oro-Medonte
# Coordinates from geopy: [44.5445701, -79.56282954629216]
# Row: 476
# Location from spacy: Innisfil
# Coordinates from geopy: [44.3150892, -79.5461073]
# Row: 477
# Location from spacy: Innisfil Beach
# Coordinates from geopy: [44.3150892, -79.5461073]
# Row: 478
# Location from spacy: Ontario
# Coordinates from geopy: [50.000678, -86.000977]
# Row: 479
# Location from spacy: Springwater Township
# Coordinates from geopy: [45.2506768, -122.3395287]
# Row: 480
# Location from spacy: CREEMORE
# Coordinates from geopy: [44.327104, -80.1084149]
# Row: 481
# Location from spacy: Ontario
# Coordinates from geopy: [50.000678, -86.000977]
# Row: 482
# Location from spacy: Barrie
# Coordinates from geopy: [44.3893113, -79.6901736]
# Row: 483
# Location from spacy: Severn Township
# Coordinates from geopy: [39.1278864, -76.6869128]
# Row: 484
# Location from spacy: Midland
# Coordinates from geopy: [31.9973662, -102.0779482]
# Row: 485
# Location from spacy:
# Row: 486
# Location from spacy: Ontario
# Coordinates from geopy: [50.000678, -86.000977]
# Row: 487
# Location from spacy: Toronto
# Coordinates from geopy: [43.6534817, -79.3839347]
# Row: 488
# Location from spacy:
# Row: 489
# Location from spacy:
# Row: 490
# Location from spacy: Wasaga Beach
# Coordinates from geopy: [44.5224813, -80.0203156]
# Row: 491
# Location from spacy: Barrie
# Coordinates from geopy: [44.3893113, -79.6901736]
# Row: 492
# Location from spacy: Bitcoin
# Coordinates from geopy: [52.3800847, 16.984005]
# Row: 493
# Location from spacy: Houston
# Coordinates from geopy: [29.7589382, -95.3676974]
# Row: 494
# Location from spacy: Singapore
# Coordinates from geopy: [1.357107, 103.8194992]
# Row: 495
# Location from spacy: U.S.
# Coordinates from geopy: [45.1895845, -88.73215845]
# Row: 496
# Location from spacy: Russia
# Coordinates from geopy: [64.6863136, 97.7453061]
# Row: 497
# Location from spacy: US
# Coordinates from geopy: [39.7837304, -100.4458825]
# Row: 498
# Location from spacy: FRANCE
# Coordinates from geopy: [46.603354, 1.8883335]
# Row: 499
# Location from spacy: California
# Coordinates from geopy: [36.7014631, -118.7559974]
# Row: 500
# Location from spacy: China
# Coordinates from geopy: [35.000074, 104.999927]
# Row: 501
# Location from spacy: OTTAWA
# Coordinates from geopy: [45.421106, -75.690308]
# Row: 502
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 503
# Location from spacy: China
# Coordinates from geopy: [35.000074, 104.999927]
# Row: 504
# Location from spacy: AI
# Coordinates from geopy: [18.1954947, -63.0750234]
# Row: 505
# Location from spacy: Barcelona
# Coordinates from geopy: [41.3828939, 2.1774322]
# Row: 506
# Location from spacy: Barcelona
# Coordinates from geopy: [41.3828939, 2.1774322]
# Row: 507
# Location from spacy: Voorhees
# Coordinates from geopy: [39.8512162, -74.9619779]
# Row: 508
# Location from spacy: North Carolina
# Coordinates from geopy: [35.6729639, -79.0392919]
# Row: 509
# Location from spacy: Toronto
# Coordinates from geopy: [43.6534817, -79.3839347]
# Row: 510
# Location from spacy: Toronto
# Coordinates from geopy: [43.6534817, -79.3839347]
# Row: 511
# Location from spacy: Florida
# Coordinates from geopy: [27.7567667, -81.4639835]
# Row: 512
# Location from spacy: LA
# Error with .
# Row: 513
# Location from spacy: Quebec
# Coordinates from geopy: [52.4760892, -71.8258668]
# Row: 514
# Location from spacy: Regina
# Coordinates from geopy: [50.44876, -104.61731]
# Row: 515
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 516
# Location from spacy: India
# Coordinates from geopy: [22.3511148, 78.6677428]
# Row: 517
# Location from spacy: Wisconsin
# Coordinates from geopy: [44.4308975, -89.6884637]
# Row: 518
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 519
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 520
# Location from spacy: OTTAWA
# Coordinates from geopy: [45.421106, -75.690308]
# Row: 521
# Location from spacy: British Columbia
# Coordinates from geopy: [55.001251, -125.002441]
# Row: 522
# Location from spacy: British Columbia
# Coordinates from geopy: [55.001251, -125.002441]
# Row: 523
# Location from spacy: the City of Victoria's
# Coordinates from geopy: [10.9013412, 123.0714943]
# Row: 524
# Location from spacy: British Columbia
# Coordinates from geopy: [55.001251, -125.002441]
# Row: 525
# Location from spacy: catamaran
# Coordinates from geopy: [-43.5519452, 146.8879282]
# Row: 526
# Location from spacy:
# Row: 527
# Location from spacy: Texada
# Coordinates from geopy: [49.6103006, -124.37309486062466]
# Row: 528
# Location from spacy: British Columbia
# Coordinates from geopy: [55.001251, -125.002441]
# Row: 529
# Location from spacy: British Columbia
# Coordinates from geopy: [55.001251, -125.002441]
# Row: 530
# Location from spacy:
# Row: 531
# Location from spacy: Tonya
# Coordinates from geopy: [40.8415543, 39.29416684591129]
# Row: 532
# Location from spacy:
# Row: 533
# Location from spacy: Bigg
# Coordinates from geopy: [43.0116532, 141.3866216]
# Row: 534
# Location from spacy: British Columbia
# Coordinates from geopy: [55.001251, -125.002441]
# Row: 535
# Location from spacy: U.S.
# Coordinates from geopy: [45.1895845, -88.73215845]
# Row: 536
# Location from spacy: U.S.
# Coordinates from geopy: [45.1895845, -88.73215845]
# Row: 537
# Location from spacy: DRIVING
# Coordinates from geopy: [13.3607906, 103.8632675]
# Row: 538
# Location from spacy: the Bronco Sport
# Error with .
# Row: 539
# Location from spacy: Quebec
# Coordinates from geopy: [52.4760892, -71.8258668]
# Row: 540
# Location from spacy: Montreal
# Coordinates from geopy: [45.4972159, -73.6103642]
# Row: 541
# Location from spacy: Japan
# Coordinates from geopy: [36.5748441, 139.2394179]
# Row: 542
# Location from spacy: Quebec
# Coordinates from geopy: [52.4760892, -71.8258668]
# Row: 543
# Location from spacy: Shanghai
# Coordinates from geopy: [31.2252985, 121.4890497]
# Row: 544
# Location from spacy: Regina Beach
# Coordinates from geopy: [50.7911888, -104.9857749]
# Row: 545
# Location from spacy: Saskatchewan
# Coordinates from geopy: [55.5321257, -106.1412243]
# Row: 546
# Location from spacy: Regina
# Coordinates from geopy: [50.44876, -104.61731]
# Row: 547
# Location from spacy: Saskatchewan
# Coordinates from geopy: [55.5321257, -106.1412243]
# Row: 548
# Location from spacy: Victoria Park
# Coordinates from geopy: [51.53904215, -0.0343110945633131]
# Row: 549
# Location from spacy: Saskatchewan
# Coordinates from geopy: [55.5321257, -106.1412243]
# Row: 550
# Location from spacy: Saskatchewan
# Coordinates from geopy: [55.5321257, -106.1412243]
# Row: 551
# Location from spacy: Saskatchewan
# Coordinates from geopy: [55.5321257, -106.1412243]
# Row: 552
# Location from spacy: Regina
# Coordinates from geopy: [50.44876, -104.61731]
# Row: 553
# Location from spacy: Tansey
# Coordinates from geopy: [31.8265562, -92.382085]
# Row: 554
# Location from spacy: Glenavon
# Coordinates from geopy: [50.1968048, -103.1389785]
# Row: 555
# Location from spacy: Saskatchewan
# Coordinates from geopy: [55.5321257, -106.1412243]
# Row: 556
# Location from spacy: Montreal
# Coordinates from geopy: [45.4972159, -73.6103642]
# Row: 557
# Location from spacy: Quebec
# Coordinates from geopy: [52.4760892, -71.8258668]
# Row: 558
# Location from spacy: Quebec
# Coordinates from geopy: [52.4760892, -71.8258668]
# Row: 559
# Location from spacy: Toronto
# Coordinates from geopy: [43.6534817, -79.3839347]
# Row: 560
# Location from spacy: Montreal
# Coordinates from geopy: [45.4972159, -73.6103642]
# Row: 561
# Location from spacy: Montreal
# Coordinates from geopy: [45.4972159, -73.6103642]
# Row: 562
# Location from spacy: Quebec
# Coordinates from geopy: [52.4760892, -71.8258668]
# Row: 563
# Location from spacy: Montreal
# Coordinates from geopy: [45.4972159, -73.6103642]
# Row: 564
# Location from spacy: Quebec
# Coordinates from geopy: [52.4760892, -71.8258668]
# Row: 565
# Location from spacy: Montreal
# Coordinates from geopy: [45.4972159, -73.6103642]
# Row: 566
# Location from spacy: MONTREAL
# Coordinates from geopy: [45.4972159, -73.6103642]
# Row: 567
# Location from spacy: Quebec
# Coordinates from geopy: [52.4760892, -71.8258668]
# Row: 568
# Location from spacy: Quebec
# Coordinates from geopy: [52.4760892, -71.8258668]
# Row: 569
# Location from spacy:
# Row: 570
# Location from spacy: Quebec
# Coordinates from geopy: [52.4760892, -71.8258668]
# Row: 571
# Location from spacy: Nickels
# Coordinates from geopy: [50.1522329, 9.591124250089779]
# Row: 572
# Location from spacy: London
# Coordinates from geopy: [51.5073219, -0.1276474]
# Row: 573
# Location from spacy: Virginia
# Coordinates from geopy: [37.1232245, -78.4927721]
# Row: 574
# Location from spacy: Quebec
# Coordinates from geopy: [52.4760892, -71.8258668]
# Row: 575
# Location from spacy: U.S.
# Coordinates from geopy: [45.1895845, -88.73215845]
# Row: 576
# Location from spacy: U.S.
# Coordinates from geopy: [45.1895845, -88.73215845]
# Row: 577
# Location from spacy: Montreal
# Coordinates from geopy: [45.4972159, -73.6103642]
# Row: 578
# Location from spacy: Portugal
# Coordinates from geopy: [40.0332629, -7.8896263]
# Row: 579
# Location from spacy: Richmond
# Coordinates from geopy: [37.5385087, -77.43428]
# Row: 580
# Location from spacy: Toronto
# Coordinates from geopy: [43.6534817, -79.3839347]
# Row: 581
# Location from spacy: North Carolina
# Coordinates from geopy: [35.6729639, -79.0392919]
# Row: 582
# Location from spacy: Los Angeles
# Coordinates from geopy: [34.0536909, -118.2427666]
# Row: 583
# Location from spacy: New York
# Coordinates from geopy: [40.7127281, -74.0060152]
# Row: 584
# Location from spacy: Calgary
# Coordinates from geopy: [51.0534234, -114.0625892]
# Row: 585
# Location from spacy: Toronto
# Coordinates from geopy: [43.6534817, -79.3839347]
# Row: 586
# Location from spacy: U.S.
# Coordinates from geopy: [45.1895845, -88.73215845]
# Row: 587
# Location from spacy: India
# Coordinates from geopy: [22.3511148, 78.6677428]
# Row: 588
# Location from spacy: Toronto
# Coordinates from geopy: [43.6534817, -79.3839347]
# Row: 589
# Location from spacy: Lehrer
# Coordinates from geopy: [49.6388884, 8.32103265]
# Row: 590
# Location from spacy: U.S.
# Coordinates from geopy: [45.1895845, -88.73215845]
# Row: 591
# Location from spacy: Calgary
# Coordinates from geopy: [51.0534234, -114.0625892]
# ...
# Row: 4141
# Location from spacy: OTTAWA
# Coordinates from geopy: [45.421106, -75.690308]
# Row: 4142
# Location from spacy: East Kootenay
# Coordinates from geopy: [54.8582888, -5.830786450000006]
# Row: 4143
# Location from spacy: Waterloo Region
# Coordinates from geopy: [43.4586422, -80.5194113]
# Row: 4144
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 4145
# Location from spacy: Ontario
# Coordinates from geopy: [50.000678, -86.000977]
# Row: 4146
# Location from spacy: Blaine
# Coordinates from geopy: [41.9195837, -99.979237]
# Row: 4147
# Location from spacy: Toronto
# Coordinates from geopy: [43.6534817, -79.3839347]
# Row: 4148
# Location from spacy: Alberta
# Coordinates from geopy: [55.001251, -115.002136]
# Row: 4149
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 4150
# Location from spacy: Toronto
# Coordinates from geopy: [43.6534817, -79.3839347]
# Row: 4151
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 4152
# Location from spacy: Ontario
# Coordinates from geopy: [50.000678, -86.000977]
# Row: 4153
# Location from spacy: Lethbridge
# Coordinates from geopy: [49.694285, -112.851562]
# Row: 4154
# Location from spacy: Hong Kong
# Coordinates from geopy: [22.2793278, 114.1628131]
# Row: 4155
# Location from spacy: Quebec City
# Coordinates from geopy: [46.8259601, -71.2352226]
# Row: 4156
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 4157
# Location from spacy: Ontario
# Coordinates from geopy: [50.000678, -86.000977]
# Row: 4158
# Location from spacy: Ontario
# Coordinates from geopy: [50.000678, -86.000977]
# Row: 4159
# Location from spacy: Ontario
# Coordinates from geopy: [50.000678, -86.000977]
# Row: 4160
# Location from spacy: Ontario
# Coordinates from geopy: [50.000678, -86.000977]
# Row: 4161
# Location from spacy: U.S.
# Coordinates from geopy: [45.1895845, -88.73215845]
# Row: 4162
# Location from spacy: Ontario
# Coordinates from geopy: [50.000678, -86.000977]
# Row: 4163
# Location from spacy: Kelowna
# Coordinates from geopy: [49.889326, -119.498291]
# Row: 4164
# Location from spacy: British Columbia
# Coordinates from geopy: [55.001251, -125.002441]
# Row: 4165
# Location from spacy: Montreal
# Coordinates from geopy: [45.4972159, -73.6103642]
# Row: 4166
# Location from spacy: Hong Kong
# Coordinates from geopy: [22.2793278, 114.1628131]
# Row: 4167
# Location from spacy: Lethbridge
# Coordinates from geopy: [49.694285, -112.851562]
# Row: 4168
# Location from spacy: Toronto
# Coordinates from geopy: [43.6534817, -79.3839347]
# Row: 4169
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 4170
# Location from spacy: Toronto
# Coordinates from geopy: [43.6534817, -79.3839347]
# Row: 4171
# Location from spacy: Alberta
# Coordinates from geopy: [55.001251, -115.002136]
# Row: 4172
# Location from spacy: Daadab
# Coordinates from geopy: [-0.7732949, 38.357783]
# Row: 4173
# Location from spacy:
# Row: 4174
# Location from spacy: Nova Scotia
# Coordinates from geopy: [45.1960403, -63.1653789]
# Row: 4175
# Location from spacy: Dorton
# Coordinates from geopy: [37.2767726, -82.5790436]
# Row: 4176
# Location from spacy: New Brunswick
# Coordinates from geopy: [46.500283, -66.750183]
# Row: 4177
# Location from spacy: Toronto
# Coordinates from geopy: [43.6534817, -79.3839347]
# Row: 4178
# Location from spacy: Toronto
# Coordinates from geopy: [43.6534817, -79.3839347]
# Row: 4179
# Location from spacy: Ontario
# Coordinates from geopy: [50.000678, -86.000977]
# Row: 4180
# Location from spacy: London
# Coordinates from geopy: [51.5073219, -0.1276474]
# Row: 4181
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 4182
# Location from spacy:
# Row: 4183
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 4184
# Location from spacy: Toronto
# Coordinates from geopy: [43.6534817, -79.3839347]
# Row: 4185
# Location from spacy: Javier
# Coordinates from geopy: [42.5911918, -1.2086914]
# Row: 4186
# Location from spacy: Canada
# Error with .
# Row: 4187
# Location from spacy: Sunset Villa
# Coordinates from geopy: [41.9083609, -88.4281341]
# Row: 4188
# Location from spacy: Canada
# Error with .
# Row: 4189
# Location from spacy: Cambridge
# Coordinates from geopy: [52.2034823, 0.1235817]
# Row: 4190
# Location from spacy: Dishes
# Coordinates from geopy: [29.9620871, 31.2755092]
# Row: 4191
# Location from spacy: Hong Kong
# Coordinates from geopy: [22.2793278, 114.1628131]
# Row: 4192
# Location from spacy: Gayuma
# Error with .
# Row: 4193
# Location from spacy: wilmotstrongertogether.ca
# Error with .
# Row: 4194
# Location from spacy: wilmotstrongertogether.ca
# Error with .
# Row: 4195
# Location from spacy: U.S.
# Coordinates from geopy: [45.1895845, -88.73215845]
# Row: 4196
# Location from spacy: Nashville
# Coordinates from geopy: [36.1622296, -86.7743531]
# Row: 4197
# Location from spacy: Waterloo
# Coordinates from geopy: [42.4979693, -92.3329637]
# Row: 4198
# Location from spacy: Toronto
# Coordinates from geopy: [43.6534817, -79.3839347]
# Row: 4199
# Location from spacy: the United Kingdom
# Coordinates from geopy: [54.7023545, -3.2765753]
# Row: 4200
# Location from spacy: Cambridge
# Coordinates from geopy: [52.2034823, 0.1235817]
# Row: 4201
# Location from spacy: Meshake
# Error with .
# Row: 4202
# Location from spacy: Rome
# Coordinates from geopy: [41.8933203, 12.4829321]
# Row: 4203
# Location from spacy: Lillian
# Coordinates from geopy: [32.5065277, -97.1875113]
# Row: 4204
# Location from spacy:
# Row: 4205
# Location from spacy: U.S.
# Coordinates from geopy: [45.1895845, -88.73215845]
# Row: 4206
# Location from spacy: Lifetime
# Coordinates from geopy: [51.1177898, 7.4162281]
# Row: 4207
# Location from spacy: Mexico
# Coordinates from geopy: [19.4326296, -99.1331785]
# Row: 4208
# Location from spacy:
# Row: 4209
# Location from spacy:
# Row: 4210
# Location from spacy: Nolan
# Coordinates from geopy: [32.2719306, -100.3987748]
# Row: 4211
# Location from spacy: Seattle
# Coordinates from geopy: [47.6038321, -122.3300624]
# Row: 4212
# Location from spacy: Ontario
# Coordinates from geopy: [50.000678, -86.000977]
# Row: 4213
# Location from spacy: Toronto
# Coordinates from geopy: [43.6534817, -79.3839347]
# Row: 4214
# Location from spacy: Ontario
# Coordinates from geopy: [50.000678, -86.000977]
# Row: 4215
# Location from spacy: premium city
# Coordinates from geopy: [14.6740331, 121.020707]
# Row: 4216
# Location from spacy: Mississauga
# Coordinates from geopy: [43.590338, -79.645729]
# Row: 4217
# Location from spacy: Hemerocallis
# Coordinates from geopy: [50.46748985, 3.9416713495644986]
# Row: 4218
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 4219
# Location from spacy: Ontario
# Coordinates from geopy: [50.000678, -86.000977]
# Row: 4220
# Location from spacy: Ontario
# Coordinates from geopy: [50.000678, -86.000977]
# Row: 4221
# Location from spacy: China
# Coordinates from geopy: [35.000074, 104.999927]
# Row: 4222
# Location from spacy: Toronto
# Coordinates from geopy: [43.6534817, -79.3839347]
# Row: 4223
# Location from spacy: Ontario
# Coordinates from geopy: [50.000678, -86.000977]
# Row: 4224
# Location from spacy: Ontario
# Coordinates from geopy: [50.000678, -86.000977]
# Row: 4225
# Location from spacy: Quebec
# Coordinates from geopy: [52.4760892, -71.8258668]
# Row: 4226
# Location from spacy: Ottawa
# Coordinates from geopy: [45.421106, -75.690308]
# Row: 4227
# Location from spacy: China
# Coordinates from geopy: [35.000074, 104.999927]
# Row: 4228
# Location from spacy: Russia
# Coordinates from geopy: [64.6863136, 97.7453061]
# Row: 4229
# Location from spacy: Quebec
# Coordinates from geopy: [52.4760892, -71.8258668]
# Row: 4230
# Location from spacy: Mexico
# Coordinates from geopy: [19.4326296, -99.1331785]
# Row: 4231
# Location from spacy: Ontario
# Coordinates from geopy: [50.000678, -86.000977]
# Row: 4232
# Location from spacy: Jena
# Coordinates from geopy: [50.9281717, 11.5879359]
# Row: 4233
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 4234
# Location from spacy: Sarnia Sting
# Error with .
# Row: 4235
# Location from spacy: Arizona Coyotes
# Coordinates from geopy: [32.2777643, -110.8618164]
# Row: 4236
# Location from spacy: Ontario
# Coordinates from geopy: [50.000678, -86.000977]
# Row: 4237
# Location from spacy: London
# Coordinates from geopy: [51.5073219, -0.1276474]
# Row: 4238
# Location from spacy:
# Row: 4239
# Location from spacy: Mississauga
# Coordinates from geopy: [43.590338, -79.645729]
# Row: 4240
# Location from spacy: London
# Coordinates from geopy: [51.5073219, -0.1276474]
# Row: 4241
# Location from spacy: Instagram
# Coordinates from geopy: [22.2890784, 114.1346515]
# Row: 4242
# Location from spacy:
# Row: 4243
# Location from spacy: Florida
# Coordinates from geopy: [27.7567667, -81.4639835]
# Row: 4244
# Location from spacy: Sporting Kansas City
# Coordinates from geopy: [39.1216438, -94.82335037131475]
# Row: 4245
# Location from spacy: Oakland
# Coordinates from geopy: [37.8044557, -122.2713563]
# Row: 4246
# Location from spacy: Obang
# Coordinates from geopy: [4.264034, 11.2600474]
# Row: 4247
# Location from spacy: Bluevale
# Coordinates from geopy: [43.8561715, -81.2493678]
# Row: 4248
# Location from spacy: St. David
# Coordinates from geopy: [40.4933728, -90.0487284]
# Row: 4249
# Location from spacy: Eagles
# Coordinates from geopy: [54.915911, -7.2864698]
# Row: 4250
# Location from spacy:
# Row: 4251
# Location from spacy: Eagles
# Coordinates from geopy: [54.915911, -7.2864698]
# Row: 4252
# Location from spacy: Burlington
# Coordinates from geopy: [44.4762975, -73.2135472]
# Row: 4253
# Location from spacy: Toronto
# Coordinates from geopy: [43.6534817, -79.3839347]
# Row: 4254
# Location from spacy: Toronto
# Coordinates from geopy: [43.6534817, -79.3839347]
# Row: 4255
# Location from spacy: Toronto
# Coordinates from geopy: [43.6534817, -79.3839347]
# Row: 4256
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 4257
# Location from spacy: Toronto
# Coordinates from geopy: [43.6534817, -79.3839347]
# Row: 4258
# Location from spacy: Toronto
# Coordinates from geopy: [43.6534817, -79.3839347]
# Row: 4259
# Location from spacy: U.S.
# Coordinates from geopy: [45.1895845, -88.73215845]
# Row: 4260
# Location from spacy: Instagram
# Coordinates from geopy: [22.2890784, 114.1346515]
# Row: 4261
# Location from spacy: Ottawa
# Coordinates from geopy: [45.421106, -75.690308]
# Row: 4262
# Location from spacy: Milwaukee
# Coordinates from geopy: [43.0349931, -87.922497]
# Row: 4263
# Location from spacy: Toronto
# Coordinates from geopy: [43.6534817, -79.3839347]
# Row: 4264
# Location from spacy: Toronto
# Coordinates from geopy: [43.6534817, -79.3839347]
# Row: 4265
# Location from spacy: Muirfield Village
# Coordinates from geopy: [33.42514, -86.619347]
# Row: 4266
# Location from spacy: Langford
# Coordinates from geopy: [48.4497693, -123.5046662]
# Row: 4267
# Location from spacy: British Columbia
# Coordinates from geopy: [55.001251, -125.002441]
# Row: 4268
# Location from spacy: U.S.
# Coordinates from geopy: [45.1895845, -88.73215845]
# Row: 4269
# Location from spacy: India
# Coordinates from geopy: [22.3511148, 78.6677428]
# Row: 4270
# Location from spacy: Kansas
# Coordinates from geopy: [38.27312, -98.5821872]
# Row: 4271
# Location from spacy: Hong Kong
# Coordinates from geopy: [22.2793278, 114.1628131]
# Row: 4272
# Location from spacy: U.S.
# Coordinates from geopy: [45.1895845, -88.73215845]
# Row: 4273
# Location from spacy: U.S.
# Coordinates from geopy: [45.1895845, -88.73215845]
# Row: 4274
# Location from spacy: Los Angeles
# Coordinates from geopy: [34.0536909, -118.2427666]
# Row: 4275
# Location from spacy: St. Louis
# Coordinates from geopy: [38.6268039, -90.1994097]
# Row: 4276
# Location from spacy: U.S.
# Coordinates from geopy: [45.1895845, -88.73215845]
# Row: 4277
# Location from spacy: U.S.
# Coordinates from geopy: [45.1895845, -88.73215845]
# Row: 4278
# Location from spacy: Mississippi
# Coordinates from geopy: [32.9715645, -89.7348497]
# Row: 4279
# Location from spacy: Michigan
# Coordinates from geopy: [43.6211955, -84.6824346]
# Row: 4280
# Location from spacy: Alaska
# Coordinates from geopy: [64.4459613, -149.680909]
# Row: 4281
# Location from spacy: U.S.
# Coordinates from geopy: [45.1895845, -88.73215845]
# Row: 4282
# Location from spacy: Rayong
# Coordinates from geopy: [12.7943716, 101.3705344]
# Row: 4283
# Location from spacy: Japan
# Coordinates from geopy: [36.5748441, 139.2394179]
# Row: 4284
# Location from spacy: China
# Coordinates from geopy: [35.000074, 104.999927]
# Row: 4285
# Location from spacy: Queensland
# Coordinates from geopy: [-22.1646782, 144.5844903]
# Row: 4286
# Location from spacy: Pakistan
# Coordinates from geopy: [30.3308401, 71.247499]
# Row: 4287
# Location from spacy: Turkey
# Coordinates from geopy: [38.9597594, 34.9249653]
# Row: 4288
# Location from spacy: Ethiopia
# Coordinates from geopy: [10.2116702, 38.6521203]
# Row: 4289
# Location from spacy: Saudi Arabia
# Coordinates from geopy: [25.6242618, 42.3528328]
# Row: 4290
# Location from spacy: Washington
# Coordinates from geopy: [38.8949855, -77.0365708]
# Row: 4291
# Location from spacy: Iran
# Coordinates from geopy: [32.6475314, 54.5643516]
# Row: 4292
# Location from spacy: Iran
# Coordinates from geopy: [32.6475314, 54.5643516]
# Row: 4293
# Location from spacy: Poland
# Coordinates from geopy: [52.215933, 19.134422]
# Row: 4294
# Location from spacy: Germany
# Coordinates from geopy: [51.0834196, 10.4234469]
# Row: 4295
# Location from spacy: Azerbaijan
# Coordinates from geopy: [40.3936294, 47.7872508]
# Row: 4296
# Location from spacy: France
# Coordinates from geopy: [46.603354, 1.8883335]
# Row: 4297
# Location from spacy: France
# Coordinates from geopy: [46.603354, 1.8883335]
# Row: 4298
# Location from spacy: Bavaria
# Coordinates from geopy: [48.9467562, 11.4038717]
# Row: 4299
# Location from spacy: Nicaragua
# Coordinates from geopy: [12.6090157, -85.2936911]
# Row: 4300
# Location from spacy: Mexico
# Coordinates from geopy: [19.4326296, -99.1331785]
# Row: 4301
# Location from spacy: Brazil
# Coordinates from geopy: [-10.3333333, -53.2]
# Row: 4302
# Location from spacy: Jalisco
# Coordinates from geopy: [20.3333331, -103.6666671]
# Row: 4303
# Location from spacy: Obrador
# Coordinates from geopy: [-34.5509699, -58.42783790541888]
# Row: 4304
# Location from spacy: Brazil
# Coordinates from geopy: [-10.3333333, -53.2]
# Row: 4305
# Location from spacy: Ethiopia
# Coordinates from geopy: [10.2116702, 38.6521203]
# Row: 4306
# Location from spacy: South Africa
# Coordinates from geopy: [-28.8166236, 24.991639]
# Row: 4307
# Location from spacy: South Africa
# Coordinates from geopy: [-28.8166236, 24.991639]
# Row: 4308
# Location from spacy: South Africa
# Coordinates from geopy: [-28.8166236, 24.991639]
# Row: 4309
# Location from spacy: Russia
# Coordinates from geopy: [64.6863136, 97.7453061]
# Row: 4310
# Location from spacy: Bamako
# Coordinates from geopy: [12.60503275, -7.986513673439357]
# Row: 4311
# Location from spacy: New Zealand
# Coordinates from geopy: [-41.5000831, 172.8344077]
# Row: 4312
# Location from spacy: Australia
# Coordinates from geopy: [-24.7761086, 134.755]
# Row: 4313
# Location from spacy: New Zealand
# Coordinates from geopy: [-41.5000831, 172.8344077]
# Row: 4314
# Location from spacy:
# Row: 4315
# Location from spacy: Ontario
# Coordinates from geopy: [50.000678, -86.000977]
# Row: 4316
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 4317
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 4318
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 4319
# Location from spacy: Ontario
# Coordinates from geopy: [50.000678, -86.000977]
# Row: 4320
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 4321
# Location from spacy: Canada
# Coordinates from geopy: [61.0666922, -107.9917071]
# Row: 4322
# Location from spacy: Wilmot Township
# Coordinates from geopy: [45.2448629, -84.67234806471632]
# Row: 4323
# Location from spacy: Toronto
# Coordinates from geopy: [43.6534817, -79.3839347]
# Row: 4324
# Location from spacy: U.S.
# Coordinates from geopy: [45.1895845, -88.73215845]
# Row: 4325
# Location from spacy: America
# Coordinates from geopy: [51.44770365, 5.966069282055592]
# Row: 4326
# Location from spacy: Ottawa
# Coordinates from geopy: [45.421106, -75.690308]
# Row: 4327
# Location from spacy: China
# Coordinates from geopy: [35.000074, 104.999927]

# %% [markdown]
# ### Exploring dataset with locations (new_clean.csv)

# %%
count_outlet
# Out:
# 684

# %%
count_spacy
# Out:
# 3585

# %%
new_clean.head()
# Out:
#   outlet                                 url  \
# 0    cbc    https://www.cbc.ca/news/covid-19
# 1    cbc       https://www.cbc.ca/news/local
# 2    cbc    https://www.cbc.ca/news/politics
# 3    cbc  https://www.cbc.ca/news/indigenous
# 4    cbc    https://www.cbc.ca/news/business
#
#                                              title             authors  \
# 0  CBC News | Information about COVID-19 in Canada  'Darren Bernhardt'
# 1                                         CBC News    'Andrew Kurjata'
# 2                                         Politics  'John Paul Tasker'
# 3                                       Indigenous      'Jessica Deer'
# 4                                         Business        'Pete Evans'
#
#   publish_date                                               text keywords  \
# 0          NaN  Sylvan Lake to clamp down on beach crowds with...       []
# 1          NaN  What you need to know about COVID-19 in Ottawa...       []
# 2          NaN  WE Charity contract could have been worth up t...       []
# 3          NaN  Manitoba judge points to systemic issues in In...       []
# 4          NaN  Twitter says about 130 accounts were targeted ...       []
#
#    location        lat        long
# 0   Alberta  55.001251 -115.002136
# 1    Ottawa  45.421106  -75.690308
# 2   Toronto  45.518055  -73.550930
# 3  Manitoba  55.001251  -97.001038
# 4   Toronto  45.518055  -73.550930

# %%
new_clean['location'].value_counts()
# Out:
# Vancouver              417
# British Columbia       319
# Toronto                285
# Burnaby                284
# Canada                 283
#                       ...
# Hydra Perfection         1
# C.Dir                    1
# hollowaypainting.ca      1
# Whonnock                 1
# Liberty Village and      1
# Name: location, Length: 896, dtype: int64

# %% [markdown]
# **Notes:**
# - Change "Surrey" to "Surrey, British Columbia"
# - Change "B.C." to "British Columbia"

# %% [markdown]
# ## Exploring geo.csv (locations of outlets)

# %%
geo = pd.read_csv('geo.csv')

# %%
clean.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-aa94614744df> in <module>
# ----> 1 clean.columns
#
# NameError: name 'clean' is not defined

# %%
geo.columns = ['outlet', 'url', 'title', 'authors', 'publish_date', 'text', 'keywords', 'scope', 'location', 'latitude', 'longitude']

# %%
geo.head()
# Out:
#     outlet                                                url  \
# 0  ctvnews  https://www.ctvnews.ca/health/coronavirus/trac...
# 1  ctvnews  https://www.ctvnews.ca/politics/liberals-revis...
# 2  ctvnews  https://www.ctvnews.ca/health/coronavirus/new-...
# 3  ctvnews  https://www.ctvnews.ca/health/coronavirus/it-s...
# 4  ctvnews  https://www.ctvnews.ca/health/coronavirus/ariz...
#
#                                                title              authors  \
# 0          Tracking every case of COVID-19 in Canada                  NaN
# 1  Liberals revise COVID-19 wage subsidy, ease el...                  NaN
# 2  New Normal: Casinos betting on temperature che...                  NaN
# 3  'It's amazing': Toronto man recovering after 1...                  NaN
# 4  Arizona man in a coma from coronavirus wakes u...  'Madeline Holcombe'
#
#                 publish_date  \
# 0  2020-03-13 14:17:00-04:00
# 1  2020-07-17 10:22:00-04:00
# 2  2020-07-17 12:03:00-04:00
# 3  2020-07-15 22:00:00-04:00
# 4  2020-07-16 08:15:00-04:00
#
#                                                 text keywords     scope  \
# 0  July 17 – Ontario health officials recorded 11...       []  national
# 1  OTTAWA -- Finance Minister Bill Morneau says t...       []  national
# 2  TORONTO -- Canadian gamblers are trading in ca...       []  national
# 3  TORONTO -- For months, Bruno Iozzo’s family wa...       []  national
# 4  For Eddie Case, recovering from COVID-19 comes...       []  national
#
#   location   latitude  longitude
# 0   Ottawa -75.697472  45.421861
# 1   Ottawa -75.697472  45.421861
# 2   Ottawa -75.697472  45.421861
# 3   Ottawa -75.697472  45.421861
# 4   Ottawa -75.697472  45.421861

# %% [markdown]
# ### Creates dictionaries from scope and location of each outlet

# %%
group = geo.groupby('outlet')

# %%
# Not all 

scope_dict = group.apply(lambda x: x['scope'].unique()).apply(pd.Series).loc[:, 0].to_dict()

# %%
loc_dict = group.apply(lambda x: x['location'].unique()).apply(pd.Series).loc[:, 0].to_dict()

# %%
lat_dict = group.apply(lambda x: x['latitude'].unique()).apply(pd.Series).loc[:, 0].to_dict()

# %%
long_dict = group.apply(lambda x: x['longitude'].unique()).apply(pd.Series).loc[:, 0].to_dict()

# %%
loc_dict['cbc'] = 'Toronto'
loc_dict['tricitynews'] = 'Port Coquitlam'
loc_dict['vancouverobserver'] = 'Vancouver'
loc_dict['vancourier'] = 'Vancouver'
loc_dict['richmond-news'] = 'Richmond'
loc_dict['burnabynow'] = 'Burnaby'
loc_dict['newwestrecord'] = 'Burnaby'
loc_dict['bowenislandundercurrent'] = 'Bowen Island'

# %%
lat_dict['cbc'] = 45.518055
lat_dict['tricitynews'] = 49.247012
lat_dict['vancouverobserver'] = -123.10096000000001
lat_dict['vancourier'] = 49.266922
lat_dict['richmond-news'] = 49.174152
lat_dict['burnabynow'] = 49.252834
lat_dict['newwestrecord'] = 49.252857
lat_dict['bowenislandundercurrent'] = 49.379632

# %%
long_dict['cbc'] = -73.550930
long_dict['tricitynews'] = -122.760220
long_dict['vancouverobserver'] = 49.318767
long_dict['vancourier'] = -123.110863
long_dict['richmond-news'] = -123.119285
long_dict['burnabynow'] = -122.917969
long_dict['newwestrecord'] = -122.916369
long_dict['bowenislandundercurrent'] = -123.338253

# %%
out_lat = pd.DataFrame(lat_dict.items(), columns=['outlet', 'lat'])
out_long = pd.DataFrame(long_dict.items(), columns=['outlet', 'long'])

# %%
out_location = pd.DataFrame(loc_dict.items(), columns=['outlet', 'location'])
out_location = pd.merge(out_location, out_lat, how='inner', on=['outlet'])
out_location = pd.merge(out_location, out_long, how='inner', on=['outlet'])

# %%
out_location.to_csv('outlet_locations.csv')

# %% [markdown]
# ### Exploring geopy API for coordinates

# %%
from geopy.geocoders import Nominatim

gl = Nominatim(user_agent='newsworthy_ml')

# %%
loc = gl.geocode('Kanye West')

# %%
loc.address
# Out:
# 'Kanye, Southern District, PLOT, Botswana'

# %%
loc.latitude
# Out:
# -24.9766112

# %%
loc.longitude
# Out:
# 25.3358859

# %% [markdown]
# ## Combining with topic modelled articles

# %%
final = pd.read_csv('complete.csv')

# %%
final = final.drop(columns='Unnamed: 0')

# %%
new_clean2 = new_clean

# %%
final.columns
# Out:
# Index(['url', 'num_articles_per_topic', 'topic_resid', 'category',
#        'category_probability', 'topic_num', 'topics', 'outlet', 'title',
#        'authors', 'publish_date', 'text', 'keywords', 'word_count',
#        'article_resid'],
#       dtype='object')

# %%
new_clean2.columns
# Out:
# Index(['outlet', 'url', 'title', 'authors', 'publish_date', 'text', 'keywords',
#        'location', 'lat', 'long'],
#       dtype='object')

# %%
new_clean2[['url', 'location', 'lat', 'long']]
# Out:
#                                                     url  location        lat  \
# 0                      https://www.cbc.ca/news/covid-19   Alberta  55.001251
# 1                         https://www.cbc.ca/news/local    Ottawa  45.421106
# 2                      https://www.cbc.ca/news/politics   Toronto  45.518055
# 3                    https://www.cbc.ca/news/indigenous  Manitoba  55.001251
# 4                      https://www.cbc.ca/news/business   Toronto  45.518055
# ...                                                 ...       ...        ...
# 4323  https://www.therecord.com/opinion/columnists/2...   Toronto  43.653482
# 4324  https://www.therecord.com/opinion/columnists/2...      U.S.  45.189585
# 4325  https://www.therecord.com/opinion/contributors...   America  51.447704
# 4326  https://www.therecord.com/opinion/contributors...    Ottawa  45.421106
# 4327  https://www.therecord.com/opinion/contributors...     China  35.000074
#
#             long
# 0    -115.002136
# 1     -75.690308
# 2     -73.550930
# 3     -97.001038
# 4     -73.550930
# ...          ...
# 4323  -79.383935
# 4324  -88.732158
# 4325    5.966069
# 4326  -75.690308
# 4327  104.999927
#
# [4328 rows x 4 columns]

# %%
new_clean2 = new_clean2[['url', 'location', 'lat', 'long']]

# %%
final_df = pd.merge(final, new_clean2, how='inner', on=['url'])

# %%
final_df.head()
# Out:
#                                                  url  num_articles_per_topic  \
# 0  https://www.cbc.ca/parents/learning/view/covid...                     222
# 1  https://www.thestar.com/life/health_wellness/2...                     222
# 2  https://www.thestar.com/life/health_wellness/2...                     222
# 3  https://www.thestar.com/life/relationships/adv...                     222
# 4  https://www.ctvnews.ca/entertainment/magic-sch...                     222
#
#    topic_resid   category  category_probability  topic_num  \
# 0     0.959933  lifestyle             86.343329          0
# 1     0.959933  lifestyle             86.343329          0
# 2     0.959933  lifestyle             86.343329          0
# 3     0.959933  lifestyle             86.343329          0
# 4     0.959933  lifestyle             86.343329          0
#
#                                       topics   outlet  \
# 0  famili just time peopl year home life day      cbc
# 1  famili just time peopl year home life day  thestar
# 2  famili just time peopl year home life day  thestar
# 3  famili just time peopl year home life day  thestar
# 4  famili just time peopl year home life day  ctvnews
#
#                                                title  \
# 0  I Don’t Know If My Kids Will Ever See Their Gr...
# 1  Why your workout may not be helping you lose w...
# 2  She lost 100 pounds and became an Instagram se...
# 3  How do I stop my adult children from being so ...
# 4  'Magic School Bus' author Joanna Cole dies at ...
#
#                        authors               publish_date  \
# 0       'Jennifer Power Scott'                 2020-07-07
# 1         'Christine Sismondo'                 2020-01-06
# 2                 'Jen Kirsch'                 2020-01-09
# 3  'Ellieadvice Columnisttue.'                 2020-07-14
# 4                          NaN  2020-07-16 07:32:00-04:00
#
#                                                 text keywords  word_count  \
# 0  On a sticky New Brunswick afternoon — the kind...       []        1120
# 1  This is the first in a week-long series on die...       []         954
# 2  This story is part of a week-long series on di...       []        1131
# 3  Q: I’m a male, 45, doing well professionally, ...       []         600
# 4  NEW YORK -- Author Joanna Cole, whose "Magic S...       []         374
#
#    article_resid      location        lat       long
# 0       0.932753  Newfoundland  49.121209 -56.696296
# 1       0.968334       Toronto  43.653482 -79.383935
# 2       0.917396        Landry  45.570000   6.739910
# 3       0.928283       Toronto -79.540139  43.779361
# 4       0.982396    Sioux City  42.496682 -96.405878

# %%
final_df.shape
# Out:
# (1786, 18)

# %%
final_df.to_csv('final_df.csv')
