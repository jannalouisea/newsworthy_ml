# %%
from pygooglenews import GoogleNews

gn = GoogleNews()

# %%
top = gn.top_news()

# %%
len(top['entries'])
# Out:
# 38

# %%
covid = gn.topic_headlines('CAAqIggKIhxDQkFTRHdvSkwyMHZNREZqY0hsNUVnSmxiaWdBUAE')

covid['entries']
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-6-23db8f250524> in <module>
# ----> 1 covid = gn.topic_headlines('CAAqIggKIhxDQkFTRHdvSkwyMHZNREZqY0hsNUVnSmxiaWdBUAE')
#       2
#       3 covid['entries']
#
# /opt/anaconda3/lib/python3.7/site-packages/pygooglenews/__init__.py in topic_headlines(self, topic, proxies, scraping_bee)
#     112             return d
#     113         else:
# --> 114             raise Exception('unsupported topic')
#     115
#     116     def geo_headlines(self, geo: str, proxies=None, scraping_bee=None):
#
# Exception: unsupported topic

# %%
ca_gn = GoogleNews('ca')

toronto = ca_gn.geo_headlines('toronto', proxies=None, scraping_bee = None)
toronto
# Out:
# {'feed': {'generator_detail': {'name': 'NFE/5.0'},
#   'generator': 'NFE/5.0',
#   'title': 'Toronto - Latest - Google News',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': '',
#    'value': 'Toronto - Latest - Google News'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'https://news.google.com/topics/CAAqIQgKIhtDQkFTRGdvSUwyMHZNR2czYURZU0FtVnVLQUFQAQ?ceid=US:en&hl=en-US&gl=US'}],
#   'link': 'https://news.google.com/topics/CAAqIQgKIhtDQkFTRGdvSUwyMHZNR2czYURZU0FtVnVLQUFQAQ?ceid=US:en&hl=en-US&gl=US',
#   'language': 'en-US',
#   'publisher': 'news-webmaster@google.com',
#   'publisher_detail': {'email': 'news-webmaster@google.com'},
#   'rights': '2020 Google Inc.',
#   'rights_detail': {'type': 'text/plain',
#    'language': None,
#    'base': '',
#    'value': '2020 Google Inc.'},
#   'updated': 'Thu, 16 Jul 2020 17:02:59 GMT',
# ...

# %%
len(toronto['entries'])
# Out:
# 70
